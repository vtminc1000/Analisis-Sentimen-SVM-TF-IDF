# %% [markdown]
# <a href="https://colab.research.google.com/github/vtminc1000/Analisis-Sentimen-SVM-TF-IDF/blob/main/01_scraping_youtube_nuklir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Project Analisis Sentimen Nuklir")
# Out:
# Project Analisis Sentimen Nuklir

# %%
# !pip install google-api-python-client pandas

# %%
from googleapiclient.discovery import build
import pandas as pd
import time

# %%
API_KEY = "AIzaSyAkogVbTY_Am_19yWdY8bX2YNWRAeLOlr4"

# %%
video_id = "DWKoP0eIqq0"

# %%
youtube = build("youtube", "v3", developerKey=API_KEY)

comments = []
next_page_token = None

while True:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,
        pageToken=next_page_token,
        textFormat="plainText"
    )

    response = request.execute()

    for item in response["items"]:
        comment = item["snippet"]["topLevelComment"]["snippet"]

        comments.append({
            "platform": "youtube",
            "video_id": video_id,
            "author": comment.get("authorDisplayName"),
            "text": comment.get("textDisplay"),
            "like_count": comment.get("likeCount"),
            "published_at": comment.get("publishedAt")
        })

    next_page_token = response.get("nextPageToken")

    if next_page_token is None:
        break

    time.sleep(0.5)

df = pd.DataFrame(comments)

print("Jumlah komentar:", len(df))
df.head()
# Out:
# Jumlah komentar: 397
#   platform     video_id                 author  \
# 0  youtube  DWKoP0eIqq0   @hamidasukmasari2566
# 1  youtube  DWKoP0eIqq0        @MuhamadAndriek
# 2  youtube  DWKoP0eIqq0         @FikiIlham-e2y
# 3  youtube  DWKoP0eIqq0              @pinjal80
# 4  youtube  DWKoP0eIqq0  @muhamadfikiilham3633
#
#                                                 text  like_count  \
# 0                                        Kemenkes RI           0
# 1    Perbanyak bikin rudal buat perang badar nanti 😂           0
# 2                      Mantap ,kpn akn di laksanakan           1
# 3  Ayo gaskan . Jgn mau ditakut takuti antek bara...           0
# 4                                        gass teruss           0
#
#            published_at
# 0  2026-04-27T08:56:27Z
# 1  2026-02-28T22:59:01Z
# 2  2026-02-27T22:51:36Z
# 3  2026-02-27T14:40:58Z
# 4  2026-02-27T13:09:01Z

# %%
df.to_csv("komentar_youtube_nuklir.csv", index=False, encoding="utf-8-sig")

# %%
from google.colab import files
files.download("komentar_youtube_nuklir.csv")

# %%
import pandas as pd

df = pd.read_csv("komentar_youtube_nuklir.csv")

df.head()
# Out:
#   platform     video_id                 author  \
# 0  youtube  DWKoP0eIqq0   @hamidasukmasari2566
# 1  youtube  DWKoP0eIqq0        @MuhamadAndriek
# 2  youtube  DWKoP0eIqq0         @FikiIlham-e2y
# 3  youtube  DWKoP0eIqq0              @pinjal80
# 4  youtube  DWKoP0eIqq0  @muhamadfikiilham3633
#
#                                                 text  like_count  \
# 0                                        Kemenkes RI           0
# 1    Perbanyak bikin rudal buat perang badar nanti 😂           0
# 2                      Mantap ,kpn akn di laksanakan           1
# 3  Ayo gaskan . Jgn mau ditakut takuti antek bara...           0
# 4                                        gass teruss           0
#
#            published_at
# 0  2026-04-27T08:56:27Z
# 1  2026-02-28T22:59:01Z
# 2  2026-02-27T22:51:36Z
# 3  2026-02-27T14:40:58Z
# 4  2026-02-27T13:09:01Z

# %%
df.columns
# Out:
# Index(['platform', 'video_id', 'author', 'text', 'like_count', 'published_at'], dtype='object')

# %%
# !pip install Sastrawi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import re
import string

# %%
def clean_text(text):

    # lowercase
    text = text.lower()

    # hapus URL
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)

    # hapus mention dan hashtag
    text = re.sub(r'@\w+|#\w+', '', text)

    # hapus angka
    text = re.sub(r'\d+', '', text)

    # hapus tanda baca
    text = text.translate(str.maketrans('', '', string.punctuation))

    # hapus spasi berlebih
    text = text.strip()

    return text

# %%
df["clean_text"] = df["text"].astype(str).apply(clean_text)

# %%
df[["text", "clean_text"]].head(10)
# Out:
#                                                 text  \
# 0                                        Kemenkes RI
# 1    Perbanyak bikin rudal buat perang badar nanti 😂
# 2                      Mantap ,kpn akn di laksanakan
# 3  Ayo gaskan . Jgn mau ditakut takuti antek bara...
# 4                                        gass teruss
# 5  Jika indonesia bangun nuklir jangan terkoneksi...
# 6                                         Mantappppp
# 7  Kita lihat apakah ambisi atau omongan nya yg b...
# 8                                  mantap pk prabowo
# 9                                              😂😂😂😂😂
#
#                                           clean_text
# 0                                        kemenkes ri
# 1    perbanyak bikin rudal buat perang badar nanti 😂
# 2                       mantap kpn akn di laksanakan
# 3  ayo gaskan  jgn mau ditakut takuti antek barat...
# 4                                        gass teruss
# 5  jika indonesia bangun nuklir jangan terkoneksi...
# ...

# %%
df = df[df["clean_text"] != ""]

# %%
df = df.drop_duplicates(subset="clean_text")

# %%
print("Jumlah data setelah cleaning:", len(df))
# Out:
# Jumlah data setelah cleaning: 395

# %%
df.to_csv("komentar_youtube_nuklir_clean.csv", index=False, encoding="utf-8-sig")

# %%
from google.colab import files
files.download("komentar_youtube_nuklir_clean.csv")

# %%
# !pip install Sastrawi nltk

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

stop_words = set(stopwords.words('indonesian'))

# %%
def preprocess_text(text):

    # stemming
    text = stemmer.stem(text)

    # stopword removal
    words = text.split()

    filtered_words = [
        word for word in words
        if word not in stop_words
    ]

    text = " ".join(filtered_words)

    return text

# %%
df["processed_text"] = df["clean_text"].apply(preprocess_text)

# %%
df[["clean_text", "processed_text"]].head(10)
# Out:
#                                           clean_text  \
# 0                                        kemenkes ri
# 1    perbanyak bikin rudal buat perang badar nanti 😂
# 2                       mantap kpn akn di laksanakan
# 3  ayo gaskan  jgn mau ditakut takuti antek barat...
# 4                                        gass teruss
# 5  jika indonesia bangun nuklir jangan terkoneksi...
# 6                                         mantappppp
# 7  kita lihat apakah ambisi atau omongan nya yg b...
# 8                                  mantap pk prabowo
# 9                                              😂😂😂😂😂
#
#                                       processed_text
# 0                                        kemenkes ri
# 1                           bikin rudal perang badar
# 2                             mantap kpn akn laksana
# 3  ayo gas jgn takut takut antek barat nuklir bah...
# 4                                        gass teruss
# 5  indonesia bangun nuklir koneksi dng jaring int...
# ...

# %%
df = df[df["processed_text"] != ""]

# %%
df.to_csv("komentar_youtube_nuklir_processed.csv", index=False, encoding="utf-8-sig")

# %%
from google.colab import files
files.download("komentar_youtube_nuklir_processed.csv")

# %%
label_df = df[["processed_text"]].copy()

label_df.head()
# Out:
#                                       processed_text
# 0                                        kemenkes ri
# 1                           bikin rudal perang badar
# 2                             mantap kpn akn laksana
# 3  ayo gas jgn takut takut antek barat nuklir bah...
# 4                                        gass teruss

# %%
label_df["label"] = ""

label_df.head()
# Out:
#                                       processed_text label
# 0                                        kemenkes ri
# 1                           bikin rudal perang badar
# 2                             mantap kpn akn laksana
# 3  ayo gas jgn takut takut antek barat nuklir bah...
# 4                                        gass teruss

# %%
label_df.to_csv("labeling_sentimen.csv", index=False, encoding="utf-8-sig")

# %%
from google.colab import files
files.download("labeling_sentimen.csv")
