# %% [markdown]
# <a href="https://colab.research.google.com/github/vtminc1000/Analisis-Sentimen-SVM-TF-IDF/blob/main/04_modeling_semiauto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, classification_report

# %%
label_df = pd.read_csv("sample_labeling_300_selesai.csv")

label_df.head()
# Out:
#                                                 text  \
# 0  Amerika siap 2 Transfer dana ke LSM / penghian...
# 1  Mulai Amerika ngacau, ingat dulu waktu indones...
# 2  Jangan dengarkan rakyat yang bilang indo blum ...
# 3  Mau disebut negara maju tapi kenyataan,,,,,,GA...
# 4                     Pakai nuklir dari rusia mantap
#
#                                           clean_text    label
# 0  amerika siap transfer dana ke lsm penghianat b...  positif
# 1  mulai amerika ngacau ingat dulu waktu indonesi...  negatif
# 2  jangan dengarkan rakyat yang bilang indo blum ...   netral
# 3  mau disebut negara maju tapi kenyataangaji upa...  positif
# 4                     pakai nuklir dari rusia mantap  positif

# %%
label_df["label"].value_counts()
# Out:
# label
# netral     176
# positif     64
# negatif     60
# Name: count, dtype: int64

# %%
X = label_df["clean_text"]
y = label_df["label"]

tfidf = TfidfVectorizer(
    ngram_range=(1, 2),
    max_features=5000
)

X_tfidf = tfidf.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

model = LinearSVC()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7166666666666667
#               precision    recall  f1-score   support
#
#      negatif       1.00      0.25      0.40        12
#       netral       0.67      1.00      0.80        35
#      positif       1.00      0.38      0.56        13
#
#     accuracy                           0.72        60
#    macro avg       0.89      0.54      0.59        60
# weighted avg       0.81      0.72      0.67        60

# %%
final_model = LinearSVC()
final_model.fit(X_tfidf, y)
# Out:
# LinearSVC()

# %%
all_df = pd.read_csv("komentar_youtube_nuklir_clean.csv")

all_df.head()
# Out:
#                                                 text  \
# 0                                        Kemenkes RI
# 1    Perbanyak bikin rudal buat perang badar nanti 😂
# 2                      Mantap ,kpn akn di laksanakan
# 3  Ayo gaskan . Jgn mau ditakut takuti antek bara...
# 4                                        gass teruss
#
#                                           clean_text
# 0                                        kemenkes ri
# 1      perbanyak bikin rudal buat perang badar nanti
# 2                       mantap kpn akn di laksanakan
# 3  ayo gaskan jgn mau ditakut takuti antek barat ...
# 4                                        gass teruss

# %%
all_X = tfidf.transform(all_df["clean_text"])

all_df["predicted_label"] = final_model.predict(all_X)

all_df.head()
# Out:
#                                                 text  \
# 0                                        Kemenkes RI
# 1    Perbanyak bikin rudal buat perang badar nanti 😂
# 2                      Mantap ,kpn akn di laksanakan
# 3  Ayo gaskan . Jgn mau ditakut takuti antek bara...
# 4                                        gass teruss
#
#                                           clean_text predicted_label
# 0                                        kemenkes ri          netral
# 1      perbanyak bikin rudal buat perang badar nanti          netral
# 2                       mantap kpn akn di laksanakan         positif
# 3  ayo gaskan jgn mau ditakut takuti antek barat ...         negatif
# 4                                        gass teruss          netral

# %%
all_df["predicted_label"].value_counts()
# Out:
# predicted_label
# netral     236
# positif     77
# negatif     73
# Name: count, dtype: int64

# %%
all_df.to_csv("dataset_sentimen_nuklir_final.csv", index=False, encoding="utf-8-sig")

# %%
from google.colab import files
files.download("dataset_sentimen_nuklir_final.csv")
